# %% [markdown]
# Pandas

# %%
import pandas as pd
import  matplotlib.pyplot as plt
import numpy as np

# %%
ipl_df =pd.read_csv('/content/IPLPlayerStat.csv')

# %%
print(ipl_df)
# Out:
#      Unnamed: 0          player  runs  boundaries  balls_faced  wickets  \
# 0             0  A Ashish Reddy   280          31          196     18.0
# 1             1        A Badoni   161          18          139      2.0
# 2             2      A Chandila     4           0            7     11.0
# 3             3        A Chopra    53           7           75      0.0
# 4             4     A Choudhary    25           2           20      5.0
# ..          ...             ...   ...         ...          ...      ...
# 600         600      Yash Dayal     0           0            1     11.0
# 601         601   Yashpal Singh    47           5           67      0.0
# 602         602     Younis Khan     3           0            7      0.0
# 603         603    Yuvraj Singh  2754         367         2207     36.0
# 604         604          Z Khan   117          13          141    102.0
#
#      balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# ...

# %%
ipl_df.head()
# Out:
#    Unnamed: 0          player  runs  boundaries  balls_faced  wickets  \
# 0           0  A Ashish Reddy   280          31          196     18.0
# 1           1        A Badoni   161          18          139      2.0
# 2           2      A Chandila     4           0            7     11.0
# 3           3        A Chopra    53           7           75      0.0
# 4           4     A Choudhary    25           2           20      5.0
#
#    balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 0         270.0          400.0       28        10.00               142.86
# 1          12.0           12.0       11        14.64               115.83
# 2         234.0          245.0       12         0.33                57.14
# 3           0.0            0.0        6         8.83                70.67
# 4         108.0          144.0        5         5.00               125.00
#
#    boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %%
ipl_df.shape
# Out:
# (605, 17)

# %%
ipl_df.tail()
# Out:
#      Unnamed: 0         player  runs  boundaries  balls_faced  wickets  \
# 600         600     Yash Dayal     0           0            1     11.0
# 601         601  Yashpal Singh    47           5           67      0.0
# 602         602    Younis Khan     3           0            7      0.0
# 603         603   Yuvraj Singh  2754         367         2207     36.0
# 604         604         Z Khan   117          13          141    102.0
#
#      balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 600         205.0          296.0        9         0.00                 0.00
# 601           0.0            0.0        4        11.75                70.15
# 602           0.0            0.0        1         3.00                42.86
# 603         882.0         1091.0      129        21.35               124.78
# 604        2276.0         2860.0       99         1.18                82.98
#
#      boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           605 non-null    int64
#  1   player               605 non-null    object
#  2   runs                 605 non-null    int64
#  3   boundaries           605 non-null    int64
#  4   balls_faced          605 non-null    int64
#  5   wickets              605 non-null    float64
#  6   balls_bowled         605 non-null    float64
#  7   runs_conceded        605 non-null    float64
#  8   matches              605 non-null    int64
#  9   batting_avg          605 non-null    float64
#  10  batting_strike_rate  605 non-null    float64
#  11  boundaries_percent   605 non-null    float64
#  12  bowling_economy      605 non-null    float64
#  13  bowling_avg          605 non-null    float64
#  14  bowling_strike_rate  605 non-null    float64
# ...

# %%
ipl_df.columns
# Out:
# Index(['Unnamed: 0', 'player', 'runs', 'boundaries', 'balls_faced', 'wickets',
#        'balls_bowled', 'runs_conceded', 'matches', 'batting_avg',
#        'batting_strike_rate', 'boundaries_percent', 'bowling_economy',
#        'bowling_avg', 'bowling_strike_rate', 'catches', 'stumpings'],
#       dtype='object')

# %%
ipl_df.isnull().sum()
# Out:
# Unnamed: 0             0
# player                 0
# runs                   0
# boundaries             0
# balls_faced            0
# wickets                0
# balls_bowled           0
# runs_conceded          0
# matches                0
# batting_avg            0
# batting_strike_rate    0
# boundaries_percent     0
# bowling_economy        0
# bowling_avg            0
# bowling_strike_rate    0
# catches                0
# stumpings              0
# dtype: int64

# %%
ipl_df.describe()
# Out:
#        Unnamed: 0         runs  boundaries  balls_faced     wickets  \
# count  605.000000   605.000000  605.000000   605.000000  605.000000
# mean   302.000000   464.428099   59.778512   373.477686   16.532231
# std    174.792734   985.272855  129.559738   764.432561   30.365560
# min      0.000000     0.000000    0.000000     1.000000    0.000000
# 25%    151.000000    15.000000    1.000000    18.000000    0.000000
# 50%    302.000000    73.000000    8.000000    73.000000    3.000000
# 75%    453.000000   326.000000   39.000000   285.000000   17.000000
# max    604.000000  6634.000000  838.000000  5266.000000  183.000000
#
#        balls_bowled  runs_conceded     matches  batting_avg  \
# count    605.000000     605.000000  605.000000   605.000000
# mean     368.801653     482.558678   32.869421    10.180380
# std      650.764782     823.838933   42.215050     9.525055
# min        0.000000       0.000000    1.000000     0.000000
# ...

# %%
ipl_df.count()
# Out:
# Unnamed: 0             605
# player                 605
# runs                   605
# boundaries             605
# balls_faced            605
# wickets                605
# balls_bowled           605
# runs_conceded          605
# matches                605
# batting_avg            605
# batting_strike_rate    605
# boundaries_percent     605
# bowling_economy        605
# bowling_avg            605
# bowling_strike_rate    605
# catches                605
# stumpings              605
# dtype: int64

# %%
ipl_df.mean(numeric_only=True)
# Out:
# Unnamed: 0               302.000000
# runs                     464.428099
# boundaries                59.778512
# balls_faced              373.477686
# wickets                   16.532231
# balls_bowled             368.801653
# runs_conceded            482.558678
# matches                   32.869421
# batting_avg               10.180380
# batting_strike_rate      100.663719
# boundaries_percent        11.804579
# bowling_economy            6.059554
# bowling_avg            28666.014132
# bowling_strike_rate    17288.203074
# catches                   11.257851
# stumpings                  0.535537
# dtype: float64

# %%
# ipl_df.std(numeric_only=True)
ipl_df.describe()
# Out:
#        Unnamed: 0         runs  boundaries  balls_faced     wickets  \
# count  605.000000   605.000000  605.000000   605.000000  605.000000
# mean   302.000000   464.428099   59.778512   373.477686   16.532231
# std    174.792734   985.272855  129.559738   764.432561   30.365560
# min      0.000000     0.000000    0.000000     1.000000    0.000000
# 25%    151.000000    15.000000    1.000000    18.000000    0.000000
# 50%    302.000000    73.000000    8.000000    73.000000    3.000000
# 75%    453.000000   326.000000   39.000000   285.000000   17.000000
# max    604.000000  6634.000000  838.000000  5266.000000  183.000000
#
#        balls_bowled  runs_conceded     matches  batting_avg  \
# count    605.000000     605.000000  605.000000   605.000000
# mean     368.801653     482.558678   32.869421    10.180380
# std      650.764782     823.838933   42.215050     9.525055
# min        0.000000       0.000000    1.000000     0.000000
# ...

# %%
ipl_df.std(numeric_only=True)
# Calculate standard deviation for 'batting_avg' (this is a single float value)
batting_avg_std = ipl_df['batting_avg'].std()
plt.figure(figsize=(12, 6))
# Plot the histogram and KDE of the 'batting_avg' column itself (which is a Series)
ipl_df['batting_avg'].plot(kind='hist', bins=15, edgecolor='black', alpha=0.7, density=True)
ipl_df['batting_avg'].plot(kind='kde', color='red', ax=plt.gca(), secondary_y=False)
plt.title('Distribution of Batting Average (Histogram with KDE)')
plt.xlabel('Batting Average')
plt.ylabel('Density / Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
ipl_df.min(numeric_only=True)
# Out:
# Unnamed: 0             0.0
# runs                   0.0
# boundaries             0.0
# balls_faced            1.0
# wickets                0.0
# balls_bowled           0.0
# runs_conceded          0.0
# matches                1.0
# batting_avg            0.0
# batting_strike_rate    0.0
# boundaries_percent     0.0
# bowling_economy        0.0
# bowling_avg            0.0
# bowling_strike_rate    0.0
# catches                0.0
# stumpings              0.0
# dtype: float64

# %%
ipl_df.max(numeric_only=True)
# Out:
# Unnamed: 0                604.00
# runs                     6634.00
# boundaries                838.00
# balls_faced              5266.00
# wickets                   183.00
# balls_bowled             4024.00
# runs_conceded            4596.00
# matches                   221.00
# batting_avg                39.34
# batting_strike_rate       400.00
# boundaries_percent        100.00
# bowling_economy            36.00
# bowling_avg            940000.00
# bowling_strike_rate    670000.00
# catches                   135.00
# stumpings                  39.00
# dtype: float64

# %%
ipl_df.sample(5)
# Out:
#      Unnamed: 0         player  runs  boundaries  balls_faced  wickets  \
# 72           72  Anureet Singh    36           3           47     18.0
# 483         483       SB Joshi     6           0           16      1.0
# 600         600     Yash Dayal     0           0            1     11.0
# 35           35        AD Nath    90           9           99      0.0
# 11           11       A Mukund    19           1           23      0.0
#
#      balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 72          430.0          636.0       22         1.64                76.60
# 483          55.0           82.0        4         1.50                37.50
# 600         205.0          296.0        9         0.00                 0.00
# 35            0.0            0.0       10         9.00                90.91
# 11            0.0            0.0        2         9.50                82.61
#
#      boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %%
ipl_df.iloc[0]
# Out:
# Unnamed: 0                          0
# player                 A Ashish Reddy
# runs                              280
# boundaries                         31
# balls_faced                       196
# wickets                          18.0
# balls_bowled                    270.0
# runs_conceded                   400.0
# matches                            28
# batting_avg                      10.0
# batting_strike_rate            142.86
# boundaries_percent              15.82
# bowling_economy                  8.89
# bowling_avg                     22.22
# bowling_strike_rate              15.0
# catches                           8.0
# stumpings                         0.0
# Name: 0, dtype: object

# %%
ipl_df.iloc[0:5]
# Out:
#    Unnamed: 0          player  runs  boundaries  balls_faced  wickets  \
# 0           0  A Ashish Reddy   280          31          196     18.0
# 1           1        A Badoni   161          18          139      2.0
# 2           2      A Chandila     4           0            7     11.0
# 3           3        A Chopra    53           7           75      0.0
# 4           4     A Choudhary    25           2           20      5.0
#
#    balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 0         270.0          400.0       28        10.00               142.86
# 1          12.0           12.0       11        14.64               115.83
# 2         234.0          245.0       12         0.33                57.14
# 3           0.0            0.0        6         8.83                70.67
# 4         108.0          144.0        5         5.00               125.00
#
#    boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %%
ipl_df[['player','runs']] if 'player' in ipl_df.columns else ipl_df.iloc[:,0:2]
# Out:
#              player  runs
# 0    A Ashish Reddy   280
# 1          A Badoni   161
# 2        A Chandila     4
# 3          A Chopra    53
# 4       A Choudhary    25
# ..              ...   ...
# 600      Yash Dayal     0
# 601   Yashpal Singh    47
# 602     Younis Khan     3
# 603    Yuvraj Singh  2754
# 604          Z Khan   117
#
# [605 rows x 2 columns]

# %%
ipl_df[ipl_df['runs'] > 500] if 'runs' in ipl_df.columns else ipl_df.head()
# Out:
#      Unnamed: 0           player  runs  boundaries  balls_faced  wickets  \
# 15           15        A Symonds   974         115          781     20.0
# 27           27   AB de Villiers  5181         667         3487      0.0
# 29           29     AC Gilchrist  2069         331         1555      1.0
# 34           34       AD Mathews   724          73          599     27.0
# 36           36       AD Russell  2039         313         1212     89.0
# ..          ...              ...   ...         ...          ...      ...
# 587         587          WP Saha  2427         307         1951      0.0
# 594         594  Y Venugopal Rao   985         114          865      6.0
# 596         596      YBK Jaiswal   547          84          410      0.0
# 597         597        YK Pathan  3222         424         2334     42.0
# 603         603     Yuvraj Singh  2754         367         2207     36.0
#
#      balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# ...

# %%
ipl_df.sort_values('runs', ascending=False).head() if 'runs' in ipl_df.columns else ipl_df.head()
# Out:
#      Unnamed: 0     player  runs  boundaries  balls_faced  wickets  \
# 569         569    V Kohli  6634         800         5266      4.0
# 462         462   S Dhawan  6244         838         5083      4.0
# 130         130  DA Warner  5883         793         4313      0.0
# 430         430  RG Sharma  5881         760         4632     15.0
# 493         493   SK Raina  5536         710         4177     25.0
#
#      balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 569         264.0          371.0      216        30.71               125.98
# 462          49.0           72.0      205        30.46               122.84
# 130           2.0            2.0      162        36.31               136.40
# 430         349.0          462.0      221        26.61               126.96
# 493         930.0         1139.0      200        27.68               132.54
#
#      boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %%
ipl_df.iloc[:,0].nunique()
# Out:
# 605

# %%
ipl_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
if {'runs','matches'}.issubset(ipl_df.columns):
  ipl_df['Runs_Per_Match'] = ipl_df['runs'] / ipl_df['matches']

# %%
ipl_df[['runs','matches','Runs_Per_Match']].head()
# Out:
#    runs  matches  Runs_Per_Match
# 0   280       28       10.000000
# 1   161       11       14.636364
# 2     4       12        0.333333
# 3    53        6        8.833333
# 4    25        5        5.000000

# %%
if 'Player_Type' not in ipl_df.columns and 'wickets' in ipl_df.columns:
  ipl_df['Player_Type'] = np.where(ipl_df['wickets'] > 50,'Bowler','Batter')
  ipl_df['Player_Type'].value_counts() if 'Player_Type' in ipl_df.columns else 'Column unavailable'

# %%
ipl_df.groupby('Player_Type')[['runs','wickets']].mean()
# Out:
#                    runs    wickets
# Player_Type
# Batter       457.321755   8.100548
# Bowler       531.448276  96.051724

# %%
ipl_df.groupby('Player_Type')[['runs','wickets']].sum()
# Out:
#                runs  wickets
# Player_Type
# Batter       250155   4431.0
# Bowler        30824   5571.0

# %%
ipl_df.groupby('Player_Type').mean(numeric_only=True)
# Out:
#              Unnamed: 0        runs  boundaries  balls_faced    wickets  \
# Player_Type
# Batter       300.674589  457.321755   59.054845   367.297989   8.100548
# Bowler       314.500000  531.448276   66.603448   431.758621  96.051724
#
#              balls_bowled  runs_conceded    matches  batting_avg  \
# Player_Type
# Batter         189.597806     254.897623  25.956124    10.767038
# Bowler        2058.879310    2629.637931  98.068966     4.647586
#
#              batting_strike_rate  boundaries_percent  bowling_economy  \
# Player_Type
# Batter                 100.33064           11.809232         5.880768
# Bowler                 103.80500           11.760690         7.745690
#
#               bowling_avg  bowling_strike_rate    catches  stumpings  \
# Player_Type
# Batter       31702.592559         19119.020274  10.036563   0.592322
# Bowler          27.938276            21.702931  22.775862   0.000000
#
#              Runs_Per_Match
# Player_Type
# ...

# %%
ipl_df.corr(numeric_only=True)
# Out:
#                      Unnamed: 0      runs  boundaries  balls_faced   wickets  \
# Unnamed: 0             1.000000  0.030574    0.029793     0.035734  0.020297
# runs                   0.030574  1.000000    0.995487     0.996647  0.000615
# boundaries             0.029793  0.995487    1.000000     0.988906 -0.004918
# balls_faced            0.035734  0.996647    0.988906     1.000000  0.001617
# wickets                0.020297  0.000615   -0.004918     0.001617  1.000000
# balls_bowled           0.025574  0.021963    0.014914     0.023729  0.984346
# runs_conceded          0.023266  0.020373    0.013215     0.021713  0.983520
# matches                0.051151  0.794865    0.781909     0.798780  0.562336
# batting_avg           -0.014655  0.637994    0.643909     0.637235 -0.286431
# batting_strike_rate   -0.068752  0.301513    0.305691     0.290133  0.007181
# boundaries_percent    -0.041737  0.256730    0.270476     0.245487 -0.025581
# ...

# %%
ipl_df.to_csv('Modified_IPL_Data.csv',index=False)

# %%
df1=pd.read_csv('Modified_IPL_Data.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0          player  runs  boundaries  balls_faced  wickets  \
# 0           0  A Ashish Reddy   280          31          196     18.0
# 1           1        A Badoni   161          18          139      2.0
# 2           2      A Chandila     4           0            7     11.0
# 3           3        A Chopra    53           7           75      0.0
# 4           4     A Choudhary    25           2           20      5.0
#
#    balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 0         270.0          400.0       28        10.00               142.86
# 1          12.0           12.0       11        14.64               115.83
# 2         234.0          245.0       12         0.33                57.14
# 3           0.0            0.0        6         8.83                70.67
# 4         108.0          144.0        5         5.00               125.00
#
#    boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %% [markdown]
# Question

# %%
print("Rows and Columns:", ipl_df.shape)

print("\nColumn Names:")
print(ipl_df.columns)

print("\nData Types:")
print(ipl_df.dtypes)
# Out:
# Rows and Columns: (605, 19)
#
# Column Names:
# Index(['Unnamed: 0', 'player', 'runs', 'boundaries', 'balls_faced', 'wickets',
#        'balls_bowled', 'runs_conceded', 'matches', 'batting_avg',
#        'batting_strike_rate', 'boundaries_percent', 'bowling_economy',
#        'bowling_avg', 'bowling_strike_rate', 'catches', 'stumpings',
#        'Runs_Per_Match', 'Player_Type'],
#       dtype='object')
#
# Data Types:
# Unnamed: 0               int64
# player                  object
# runs                     int64
# boundaries               int64
# balls_faced              int64
# wickets                float64
# balls_bowled           float64
# runs_conceded          float64
# matches                  int64
# batting_avg            float64
# batting_strike_rate    float64
# boundaries_percent     float64
# bowling_economy        float64
# bowling_avg            float64
# bowling_strike_rate    float64
# catches                float64
# stumpings              float64
# ...

# %%
top_player = ipl_df.loc[ipl_df['runs'].idxmax()]

print("Top Scorer:")
print(top_player)
# Out:
# Top Scorer:
# Unnamed: 0                   569
# player                   V Kohli
# runs                        6634
# boundaries                   800
# balls_faced                 5266
# wickets                      4.0
# balls_bowled               264.0
# runs_conceded              371.0
# matches                      216
# batting_avg                30.71
# batting_strike_rate       125.98
# boundaries_percent         15.19
# bowling_economy             8.43
# bowling_avg                92.75
# bowling_strike_rate         66.0
# catches                     93.0
# stumpings                    0.0
# Runs_Per_Match         30.712963
# Player_Type               Batter
# Name: 569, dtype: object

# %%
top_wicket_taker = ipl_df.loc[ipl_df['wickets'].idxmax()]

print("Player:", top_wicket_taker['player'])
print("Wickets:", top_wicket_taker['wickets'])
# Out:
# Player: DJ Bravo
# Wickets: 183.0

# %%
# Players with batting strike rate above 150

high_sr_players = ipl_df[ipl_df['batting_strike_rate'] > 150]

print(high_sr_players[['player', 'batting_strike_rate']])
# Out:
#               player  batting_strike_rate
# 36        AD Russell               168.23
# 66   Aman Hakim Khan               166.67
# 74        Avesh Khan               163.16
# 83        B Stanlake               250.00
# 91       BCJ Cutting               163.01
# 93         BJ Haddin               163.64
# 99      Bipul Sharma               150.81
# 118    CR Brathwaite               150.83
# 125      D Pretorius               157.14
# 167       ER Dwivedi               160.00
# 200       I Malhotra               175.00
# 218        JC Archer               152.34
# 234        JM Sharma               157.05
# 245        K Gowtham               161.74
# 258        KJ Abbott               162.50
# 260        KK Cooper               165.71
# 266  KMDN Kulasekara               166.67
# 275     Kamran Akmal               164.10
# 287        LJ Wright               168.25
# 292   LS Livingstone               155.97
# 372         OC McCoy               160.00
# ...

# %%
lowest_economy_bowler = ipl_df.loc[ipl_df['bowling_economy'].idxmin()]

print(lowest_economy_bowler[['player', 'bowling_economy']])
# Out:
# player             A Chopra
# bowling_economy         0.0
# Name: 3, dtype: object
